# %% [markdown]
# # Molecular Bioactivity Prediction
# **500k ChEMBL compounds → Morgan Fingerprints → PyTorch Neural Network**
#
# > Runtime → Change runtime type → **T4 GPU** before running

# %%
# !pip install scikit-learn matplotlib --quiet

# %% [markdown]
# ## Step 1 — Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np

# Update this path if you saved the files in a subfolder
DRIVE_PATH = '/content/drive/MyDrive'

X = np.load(f'{DRIVE_PATH}/fingerprints_X.npy')
y = np.load(f'{DRIVE_PATH}/labels_y.npy')

print(f'Compounds : {X.shape[0]:,}')
print(f'Features  : {X.shape[1]}')
print(f'Active    : {y.sum():,.0f} ({y.mean()*100:.1f}%)')
print(f'Inactive  : {(1-y).sum():,.0f} ({(1-y.mean())*100:.1f}%)')

# %% [markdown]
# ## Step 2 — Upload model.py

# %%
from google.colab import files
print('Upload model.py from your neural_network/ folder')
files.upload()

# %% [markdown]
# ## Step 3 — Check GPU

# %%
import torch
print('GPU available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))

# %% [markdown]
# ## Step 4 — Train
# 30 epochs, ~10-15 min on T4 GPU

# %%
# %run model.py

# %% [markdown]
# ## Step 5 — Save model back to Drive + download

# %%
import shutil

# Save to Drive so it persists even if session ends
shutil.copy('best_model.pt', f'{DRIVE_PATH}/best_model.pt')
shutil.copy('training_history.png', f'{DRIVE_PATH}/training_history.png')
print('Saved to Google Drive')

# Also download directly
files.download('best_model.pt')
files.download('training_history.png')
